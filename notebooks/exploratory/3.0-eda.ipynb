# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
from pingouin import ttest, anova

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ---

# %%
loan_borrowers = pd.read_csv('../../data/interim/loan_borrower.csv')

# %%
loan_borrowers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_id                     100000 non-null  int64
#  1   member_id                   100000 non-null  int64
#  2   date                        100000 non-null  object
#  3   purpose                     100000 non-null  object
#  4   is_joint_application        99029 non-null   float64
#  5   loan_amount                 99983 non-null   float64
#  6   term                        99983 non-null   object
#  7   term_in_months              99983 non-null   float64
#  8   interest_rate               100000 non-null  float64
#  9   monthly_payment             100000 non-null  int64
#  10  grade                       100000 non-null  object
#  11  loan_status                 100000 non-null  object
#  12  residential_state           100000 non-null  object
#  13  years_employment            100000 non-null  object
#  14  home_ownership              100000 non-null  object
#  15  annual_income               100000 non-null  int64
#  16  income_verified             100000 non-null  int64
#  17  dti_ratio                   100000 non-null  float64
#  18  length_credit_history       100000 non-null  int64
#  19  n_total_credit_lines        100000 non-null  int64
#  20  n_open_credit_lines         99033 non-null   float64
#  21  n_open_credit_lines_1_year  100000 non-null  int64
#  22  revolving_balance           100000 non-null  int64
#  23  revolving_utilization_rate  100000 non-null  float64
#  24  n_derogatory_record         100000 non-null  int64
#  25  n_delinquency_2_years       100000 non-null  int64
#  26  n_charge_off_1_year         100000 non-null  int64
#  27  n_inquiries_6_months        100000 non-null  int64
# dtypes: float64(7), int64(13), object(8)
# memory usage: 21.4+ MB

# %%
loan_borrowers.head()
# Out:
#    loan_id  member_id        date             purpose  is_joint_application  \
# 0  1888978    2305095  2014-12-10  Debt Consolidation                   0.0
# 1  1299695    2610493  2014-09-15  Debt Consolidation                   0.0
# 2  1875016    2491679  2014-09-11  Debt Consolidation                   0.0
# 3  1440478    2092798  2016-04-22    Home Improvement                   0.0
# 4  1124634    2633077  2016-02-03  Debt Consolidation                   0.0
#
#    loan_amount       term  term_in_months  interest_rate  monthly_payment  \
# 0      25190.0  60 months            60.0           6.25              490
# 1      21189.0  60 months            60.0          10.49              455
# 2      29908.0  60 months            60.0           9.11              622
# 3      13053.0  48 months            48.0          11.89              343
# 4      24613.0  60 months            60.0          15.13              587
#
#   grade loan_status residential_state years_employment home_ownership  \
# 0    E3     Current                NM        10+ years           rent
# 1    B3     Current                WA        2-5 years           rent
# 2    B2     Current                MS         < 1 year           rent
# 3    B3     Current                TX        6-9 years            own
# 4    A3     Current                MA        2-5 years           rent
#
#    annual_income  income_verified  dti_ratio  length_credit_history  \
# 0          56471                1      16.80                      6
# 1          55038                0      19.99                     22
# 2          56610                1      14.33                      5
# 3          54887                1      14.80                     12
# 4          53522                1      10.14                      4
#
#    n_total_credit_lines  n_open_credit_lines  n_open_credit_lines_1_year  \
# 0                    11                  9.0                           6
# 1                     8                  7.0                           4
# 2                     8                  5.0                           5
# 3                    14                  7.0                           3
# 4                    21                 19.0                          10
#
#    revolving_balance  revolving_utilization_rate  n_derogatory_record  \
# 0              14301                       49.02                    0
# 1              18262                       72.40                    1
# 2              10799                       66.27                    0
# 3              15272                       61.05                    1
# 4              19316                       56.39                    2
#
#    n_delinquency_2_years  n_charge_off_1_year  n_inquiries_6_months
# 0                     19                   10                     0
# 1                      0                    0                     0
# 2                      1                    1                     0
# 3                      0                    0                     3
# 4                     14                    7                     1

# %%
loan_borrowers.tail()
# Out:
#        loan_id  member_id        date             purpose  \
# 99995  1208167    2069462  2016-05-25  Debt Consolidation
# 99996  1097349    2218175  2015-06-05  Debt Consolidation
# 99997  1873914    2262127  2014-11-13  Debt Consolidation
# 99998  1572282    2501174  2015-06-06  Debt Consolidation
# 99999  1877390    2134068  2015-08-10               Other
#
#        is_joint_application  loan_amount       term  term_in_months  \
# 99995                   0.0      25874.0  60 months            60.0
# 99996                   0.0      18557.0  60 months            60.0
# 99997                   0.0      15877.0  36 months            36.0
# 99998                   0.0      15601.0  60 months            60.0
# 99999                   0.0      20500.0  48 months            48.0
#
#        interest_rate  monthly_payment grade loan_status residential_state  \
# 99995          10.95              562    A2     Current                LA
# 99996           5.31              353    A1     Current                MO
# 99997           9.87              511    A2     Current                DE
# 99998           7.31              311    C3     Current                CA
# 99999          12.98              550    A2     Current                MN
#
#       years_employment home_ownership  annual_income  income_verified  \
# 99995        2-5 years            own          58987                0
# 99996        6-9 years           rent          54245                1
# 99997           1 year           rent          54923                0
# 99998           1 year            own          57809                1
# 99999        6-9 years           rent          52150                1
#
#        dti_ratio  length_credit_history  n_total_credit_lines  \
# 99995      21.62                      2                    16
# 99996      15.60                     11                    11
# 99997      13.96                      2                    21
# 99998       9.07                     36                    18
# 99999      11.35                      6                    13
#
#        n_open_credit_lines  n_open_credit_lines_1_year  revolving_balance  \
# 99995                 10.0                           8              15113
# 99996                  7.0                           4              13504
# 99997                 13.0                          10              18108
# 99998                 12.0                           4              17918
# 99999                 13.0                           5              17487
#
#        revolving_utilization_rate  n_derogatory_record  n_delinquency_2_years  \
# 99995                       77.01                    0                      6
# 99996                       80.18                    0                      0
# 99997                       77.28                    0                      0
# 99998                       61.01                   10                      0
# 99999                       89.47                    0                      0
#
#        n_charge_off_1_year  n_inquiries_6_months
# 99995                    5                    18
# 99996                    0                     1
# 99997                    0                     1
# 99998                    0                     1
# 99999                    0                     1

# %% [markdown]
# ----

# %% [markdown]
# # <center>**Expectations**</center>

# %% [markdown]
# **Loan Nature**
# - loan terms &uarr; &rarr; PD &uarr;
# - loan grade &darr; &rarr; PD &uarr;
# - purpose for debt consolidation &rarr; PD &uarr;
# - joint application &rarr; PD &uarr;
#
# **Employment History**
# - annual income &darr; &rarr; PD &uarr;
# - debt-to-income ratio &uarr; &rarr; PD &uarr;
# - On mortgage or renting &rarr; PD &uarr;
# - (income not verified) and (loan amount &uarr;) &rarr; PD &uarr;
# - (loan term &uarr;) and (monthly payment &uarr;) and (annual income &darr;) &rarr; PD &uarr;
#
# **Credit History**
# - (credit history length &darr;) and (number of total credit lines &uarr;) and (number of open credit lines &darr;) &rarr; PD &uarr;
# - (credit history length &darr;) or (number of delinquencies &uarr;) &rarr; PD &uarr;
# - (number of derogatory records &uarr;) or (number of delinquencies &uarr;) or (number of charge-off &uarr;) &rarr; PD &uarr;
# - (total credit lines - open credit lines) &uarr; &rarr; PD &uarr;
# - revolving utilization rate &uarr; &rarr; PD &uarr;
# - number of hard inquries within half a year &uarr; ==> urgent need to expand credit limit &rarr; PD &uarr;

# %% [markdown]
# ---

# %% [markdown]
# # <center>**Findings**</center>

# %% [markdown]
# ---

# %% [markdown]
# - There is something going on behind the healthcare loans
# - Difference due to income verification is basically negligible
# - Shortest term loan borrowers on about the same loan amount turn out to have the highest pressure to pay monthly compared with their longer term counterparts
# - Defaulters are likely to have a wide range of closed credit lines reopened, given that they have a short credit history
# - Borrowers can be split into two groups based on revovling utilization rate:
#    1. Fully Utilized Group
#    2. Non-Fully Utilized Group

# %% [markdown]
# ---
